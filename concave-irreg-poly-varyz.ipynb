# %%
from main import *

# %% [markdown]
# ## Concave irregular poly

# %%
DirList=["OCC_step_irreg_hexahedron_concave/al_0.01_mu_32_sig_1e7/1e1-1e8_40_el_21908_ord_3_POD_13_1e-7/Data/"]

MaxOmega=1e8
for directory in DirList:
    print(directory)
    RIResultsz0,RtildeIResultsz0,N0IResultsz0=main(directory,MaxOmega,Figures="On")

DirList=["OCC_step_irreg_hexahedron_concave_z=0.4/al_0.01_mu_32_sig_1e7/1e1-1e8_40_el_23811_ord_4_POD_13_1e-6/Data/"]
for directory in DirList:
    print(directory)
    RIResultsz0_4,RtildeIResultsz0_4, N0IResultsz0_4=main(directory,MaxOmega,Figures="On")

DirList=["OCC_step_irreg_hexahedron_concave_z=0.6/al_0.01_mu_32_sig_1e7/1e1-1e8_40_el_24398_ord_4_POD_13_1e-6/Data/"]
for directory in DirList:
    print(directory)
    RIResultsz0_6,RtildeIResultsz0_6,N0IResultsz0_6=main(directory,MaxOmega,Figures="On")
# Out:
# OCC_step_irreg_hexahedron_concave/al_0.01_mu_32_sig_1e7/1e1-1e8_40_el_21908_ord_3_POD_13_1e-7/Data/
# Opening files from this path =  OCC_step_irreg_hexahedron_concave/al_0.01_mu_32_sig_1e7/1e1-1e8_40_el_21908_ord_3_POD_13_1e-7/Data/
# 6
# R [-5.27903855e-10 -4.03289212e-10 -3.52834459e-10] [[ 0.40412234  0.86780301  0.28914196]
#  [ 0.90841057 -0.34374279 -0.23797298]
#  [ 0.1071232  -0.35882981  0.92723556]] 1
# Rtilde [2.76205999e-06 2.21982767e-06 1.36680058e-06] [[ 0.44684477  0.87209744  0.19943872]
#  [ 0.89228771 -0.45052578 -0.02914036]
#  [-0.06443905 -0.19097793  0.97947692]] 1
# I [2.26965019e-08 1.73236536e-08 1.25899208e-08] [[ 0.44994027  0.87677779  0.16974822]
#  [ 0.8923873  -0.4487743  -0.04739756]
#  [-0.03462151 -0.17280722  0.984347  ]] 1
# 7
# R [-1.20460903e-09 -9.20148180e-10 -8.04481523e-10] [[ 0.40438133  0.86811203  0.28784933]
#  [ 0.9084124  -0.34471821 -0.23655078]
#  [ 0.10612567 -0.35714262  0.92800134]] 1
# Rtilde [2.76138949e-06 2.21931196e-06 1.36634158e-06] [[ 0.44685666  0.87209198  0.19943595]
#  [ 0.89227978 -0.45054334 -0.02911175]
#  [-0.06446642 -0.19096144  0.97947833]] 1
# I [3.42794681e-08 2.61635516e-08 1.90040100e-08] [[ 0.45002315  0.87675773  0.16963208]
#  [ 0.89233605 -0.4489088  -0.04708788]
#  [-0.03486467 -0.17255945  0.98438188]] 1
# 6 1.0
# [-5.27903855e-10 -3.52834459e-10 -4.03289212e-10] [1.73236536e-08 1.25899208e-08 2.26965019e-08]
# [[ 0.40412234  0.28914196  0.86780301]
#  [ 0.90841057 -0.23797298 -0.34374279]
# 0.058909965097871594 1.556662076324588
# 0.0833112716003357 1.9858159231322878
# 7 1.0
# [2.93931540e-06 2.33631266e-06 1.54002575e-06] [3.63186031e-08 5.21131215e-08 2.60267610e-08]
# [[ 0.44436865  0.86946116  0.21580965]
#  [ 0.89480901 -0.44236024 -0.06028471]
#  [-0.04305039 -0.21989706  0.9745727 ]] [[ 0.8858724  -0.42564859  0.18453554]
#  [-0.43082494 -0.90233993 -0.01313457]
#  [-0.1721045   0.06786696  0.98273807]]
# 0.05906529377658165 1.556758991242683
# 0.08353093952439297 1.9859135182028727

# %%
Label=[", $V_9(0.62,0.735,0.2)$", ", $V_9(0.62,0.735,0.4)$", ", $V_9(0.62,0.735,0.6)$"]
count=0
fig=plt.figure()
for RIResults in [RIResultsz0,RIResultsz0_4,RIResultsz0_6]:
    Frequencies=RIResults["Frequencies"]
    MinAnglestoreRI=RIResults["MinAnglestoreRI"]
    dFMinAnglestoreRI = RIResults["dFMinAnglestoreRI"]
    plt.semilogx(Frequencies,MinAnglestoreRI,label=r'$d_R({\cal R},{\cal I})$ '+Label[count])
    count=count+1
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,1.0)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dR_metrics_al_0.01_mu_32_sig_1e7_varyz.pdf")
plt.show()

count=0
fig=plt.figure()
for RIResults in [RIResultsz0,RIResultsz0_4,RIResultsz0_6]:
    Frequencies=RIResults["Frequencies"]
    MinAnglestoreRI=RIResults["MinAnglestoreRI"]
    dFMinAnglestoreRI = RIResults["dFMinAnglestoreRI"]
    plt.semilogx(Frequencies,dFMinAnglestoreRI/np.sqrt(2),label=r'$d_F({\cal R},{\cal I})/\sqrt{2}$'+Label[count])
    count=count+1
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,1.0)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dF_metrics_al_0.01_mu_32_sig_1e7_varyz.pdf")
plt.show()



count=0
fig=plt.figure()
for RIResults in [RIResultsz0,RIResultsz0_4,RIResultsz0_6]:
    Frequencies=RIResults["Frequencies"]
    AnglestoreRIcommeasapprxconstsortedmaxdiff_max=np.fmin(RIResults["AnglestoreRIcommeasapprxconstsortedmaxdiff_max"],RIResults["AnglestoreRIcommeasapprxconstsortedmindiff_min"])
    plt.semilogx(Frequencies,AnglestoreRIcommeasapprxconstsortedmaxdiff_max,'-x',label=r'$\theta(d_C({\cal R},{\cal I}))$ LB '+Label[count])
    count=count+1
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,1.0)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dC_metrics_al_0.01_mu_32_sig_1e7_varyz.pdf")
plt.show()


count=0
fig=plt.figure()
for RIResults in [RIResultsz0,RIResultsz0_4,RIResultsz0_6]:
    Frequencies=RIResults["Frequencies"]
    AnglestoreRIfmeasapprxconstsortedmaxdiff_max=np.fmin(RIResults["AnglestoreRIfmeasapprxconstsortedmaxdiff_max"],RIResults["AnglestoreRIfmeasapprxconstsortedmindiff_min"])
    plt.semilogx(Frequencies,AnglestoreRIfmeasapprxconstsortedmaxdiff_max,'-x',label=r'$\theta(d_E({\cal R},{\cal I}))$ LB'+Label[count])
    count=count+1
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,1.0)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dE_metrics_al_0.01_mu_32_sig_1e7_varyz.pdf")
plt.show()

# %%
Label=[", $V_9(0.62,0.735,0.2)$", ", $V_9(0.62,0.735,0.4)$", ", $V_9(0.62,0.735,0.6)$"]
count=0
fig=plt.figure()
for RtildeIResults in [RtildeIResultsz0,RtildeIResultsz0_4,RtildeIResultsz0_6]:
    Frequencies=RtildeIResults["Frequencies"]
    MinAnglestoreRtildeI=RtildeIResults["MinAnglestoreRtildeI"]
    dFMinAnglestoreRtildeI = RtildeIResults["dFMinAnglestoreRtildeI"]
    plt.semilogx(Frequencies,MinAnglestoreRtildeI,label=r'$d_R(\tilde{\cal R},{\cal I})$ '+Label[count])
    count=count+1
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,1.0)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dR_tilde_metrics_al_0.01_mu_32_sig_1e7_varyz.pdf")
plt.show()


count=0
fig=plt.figure()
for RtildeIResults in [RtildeIResultsz0,RtildeIResultsz0_4,RtildeIResultsz0_6]:
    Frequencies=RtildeIResults["Frequencies"]
    MinAnglestoreRtildeI=RtildeIResults["MinAnglestoreRtildeI"]
    dFMinAnglestoreRtildeI = RtildeIResults["dFMinAnglestoreRtildeI"]
    plt.semilogx(Frequencies,dFMinAnglestoreRtildeI/np.sqrt(2),label=r'$d_F(\tilde{\cal R},{\cal I})/\sqrt{2}$'+Label[count])
    count=count+1
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,1.0)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dF_tilde_metrics_al_0.01_mu_32_sig_1e7_varyz.pdf")
plt.show()

count=0
fig=plt.figure()
for RtildeIResults in [RtildeIResultsz0,RtildeIResultsz0_4,RtildeIResultsz0_6]:
    Frequencies=RtildeIResults["Frequencies"]
    AnglestoreRtildeIcommeasapprxconstsortedmaxdiff_max=np.fmin(RtildeIResults["AnglestoreRtildeIcommeasapprxconstsortedmaxdiff_max"],RtildeIResults["AnglestoreRtildeIcommeasapprxconstsortedmindiff_min"])
    plt.semilogx(Frequencies,AnglestoreRtildeIcommeasapprxconstsortedmaxdiff_max,'-x',label=r'$\theta(d_C(\tilde{\cal R},{\cal I}))$ LB '+Label[count])
    count=count+1
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,1.0)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dC_tilde_metrics_al_0.01_mu_32_sig_1e7_varyz.pdf")
plt.show()

count=0
fig=plt.figure()
for RtildeIResults in [RtildeIResultsz0,RtildeIResultsz0_4,RtildeIResultsz0_6]:
    Frequencies=RtildeIResults["Frequencies"]
    AnglestoreRtildeIfmeasapprxconstsortedmaxdiff_max=np.fmin(RtildeIResults["AnglestoreRtildeIfmeasapprxconstsortedmaxdiff_max"],RtildeIResults["AnglestoreRtildeIfmeasapprxconstsortedmindiff_min"])
    plt.semilogx(Frequencies,AnglestoreRtildeIfmeasapprxconstsortedmaxdiff_max,'-x',label=r'$\theta(d_E(\tilde{\cal R},{\cal I}))$ LB'+Label[count])
    count=count+1
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,1.0)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dE_tilde_metrics_al_0.01_mu_32_sig_1e7_varyz.pdf")
plt.show()

# %%
Label=[", $V_9(0.62,0.735,0.2)$", ", $V_9(0.62,0.735,0.4)$", ", $V_9(0.62,0.735,0.6)$"]
count=0
fig=plt.figure()
for N0IResults in [N0IResultsz0,N0IResultsz0_4,N0IResultsz0_6]:
    Frequencies=N0IResults["Frequencies"]
    MinAnglestoreN0I=N0IResults["MinAnglestoreN0I"]
    dFMinAnglestoreN0I = N0IResults["dFMinAnglestoreN0I"]
    plt.semilogx(Frequencies,MinAnglestoreN0I,label=r'$d_R({\cal N}^{(0)},{\cal I})$ '+Label[count])
    count=count+1
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,1.0)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dR_N0_metrics_al_0.01_mu_32_sig_1e7_varyz.pdf")
plt.show()


count=0
fig=plt.figure()
for N0IResults in [N0IResultsz0,N0IResultsz0_4,N0IResultsz0_6]:
    Frequencies=N0IResults["Frequencies"]
    MinAnglestoreN0I=N0IResults["MinAnglestoreN0I"]
    dFMinAnglestoreN0I = N0IResults["dFMinAnglestoreN0I"]
    plt.semilogx(Frequencies,dFMinAnglestoreN0I/np.sqrt(2),label=r'$d_F({\cal N}^{(0)},{\cal I})/\sqrt{2}$'+Label[count])
    count=count+1
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,1.0)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dF_N0_metrics_al_0.01_mu_32_sig_1e7_varyz.pdf")
plt.show()

count=0
fig=plt.figure()
for N0IResults in [N0IResultsz0,N0IResultsz0_4,N0IResultsz0_6]:
    Frequencies=N0IResults["Frequencies"]
    AnglestoreN0Icommeasapprxconstsortedmaxdiff_max=np.fmin(N0IResults["AnglestoreN0Icommeasapprxconstsortedmaxdiff_max"],N0IResults["AnglestoreN0Icommeasapprxconstsortedmindiff_min"])
    plt.semilogx(Frequencies,AnglestoreN0Icommeasapprxconstsortedmaxdiff_max,'-x',label=r'$\theta(d_C({\cal N}^{(0)},{\cal I}))$ LB '+Label[count])
    count=count+1
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,1.0)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dC_N0_metrics_al_0.01_mu_32_sig_1e7_varyz.pdf")
plt.show()

count=0
fig=plt.figure()
for N0IResults in [N0IResultsz0,N0IResultsz0_4,N0IResultsz0_6]:
    Frequencies=N0IResults["Frequencies"]
    AnglestoreN0Ifmeasapprxconstsortedmaxdiff_max=np.fmin(N0IResults["AnglestoreN0Ifmeasapprxconstsortedmaxdiff_max"],N0IResults["AnglestoreN0Ifmeasapprxconstsortedmindiff_min"])
    plt.semilogx(Frequencies,AnglestoreN0Ifmeasapprxconstsortedmaxdiff_max,'-x',label=r'$\theta(d_E({\cal N}^{(0)},{\cal I}))$ LB'+Label[count])
    count=count+1
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,1.0)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dE_N0_metrics_al_0.01_mu_32_sig_1e7_varyz.pdf")
plt.show()

# %%
   
    plt.semilogx(Frequencies,dFMinAnglestoreRI/np.sqrt(2),label=r'$d_F({\cal R},{\cal I})/\sqrt{2}$')
    
AnglestoreRIfmeasapprxconstsortedmaxdiff_max=np.fmin(RIResults["AnglestoreRIfmeasapprxconstsortedmaxdiff_max"],RIResults["AnglestoreRIfmeasapprxconstsortedmindiff_min"])
AnglestoreRIcommeasapprxconstsortedmaxdiff_max=np.fmin(RIResults["AnglestoreRIcommeasapprxconstsortedmaxdiff_max"],RIResults["AnglestoreRIcommeasapprxconstsortedmindiff_min"])
AnglestoreRIcommeasapprxconstsortedmaxdiff_max=np.fmin(RIResults["AnglestoreRIcommeasapprxconstsortedmaxdiff_max"],RIResults["AnglestoreRIcommeasapprxconstsortedmindiff_min"])

dFMinAnglestoreRI = RIResults["dFMinAnglestoreRI"]
fig=plt.figure()
plt.semilogx(Frequencies,MinAnglestoreRI,label=r'$d_R({\cal R},{\cal I})$')
plt.semilogx(Frequencies,dFMinAnglestoreRI/np.sqrt(2),label=r'$d_F({\cal R},{\cal I})/\sqrt{2}$')
plt.semilogx(Frequencies,AnglestoreRIfmeasapprxconstsortedmaxdiff_max,'x',label=r'$\theta(d_E({\cal R},{\cal I}))$ ')
plt.semilogx(Frequencies,AnglestoreRIcommeasapprxconstsortedmaxdiff_max,'x',label=r'$\theta(d_C({\cal R},{\cal I}))$ ')

plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,0.8)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dRanddE_metrics_al_0.01_mu_32_sig_1e7_ord3.pdf")
plt.show()

# %%
print(RtildeIResults.keys())

Frequencies=RtildeIResults["Frequencies"]
MinAnglestoreRtildeI=RtildeIResults["MinAnglestoreRtildeI"]
AnglestoreRtildeIfmeasapprxconstsortedmaxdiff_max=np.fmin(RtildeIResults["AnglestoreRtildeIfmeasapprxconstsortedmaxdiff_max"],RtildeIResults["AnglestoreRtildeIfmeasapprxconstsortedmindiff_min"])
AnglestoreRtildeIcommeasapprxconstsortedmaxdiff_max=np.fmin(RtildeIResults["AnglestoreRtildeIcommeasapprxconstsortedmaxdiff_max"],RIResults["AnglestoreRIcommeasapprxconstsortedmindiff_min"])

dFMinAnglestoreRtildeI = RtildeIResults["dFMinAnglestoreRtildeI"]

fig=plt.figure()
plt.semilogx(Frequencies,MinAnglestoreRtildeI,label=r'$d_R(\tilde{\cal R},{\cal I})$')
plt.semilogx(Frequencies,dFMinAnglestoreRtildeI/np.sqrt(2),label=r'$d_F(\tilde{\cal R},{\cal I})/\sqrt{2}$')
plt.semilogx(Frequencies,AnglestoreRtildeIfmeasapprxconstsortedmaxdiff_max,'x',label=r'$\theta(d_E(\tilde{\cal R},{\cal I}))$ ')
plt.semilogx(Frequencies,AnglestoreRtildeIcommeasapprxconstsortedmaxdiff_max,'x',label=r'$\theta(d_C(\tilde{\cal R},{\cal I}))$ ')

plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.ylim(0,0.8)
plt.legend()
plt.savefig("OCC_step_irreg_hexahedron_concave_dRanddE_metrics_tilde_al_0.01_mu_32_sig_1e7_ord3.pdf")
plt.show()
# Out:
# dict_keys(['Frequencies', 'MinAnglestoreRtildeI', 'AnglestoreRtildeIfmeasapprxconstsortedmaxdiff_max', 'AnglestoreRtildeIfmeasapprxconstsortedmindiff_min', 'dFMinAnglestoreRtildeI', 'dFMaxAnglestoreRtildeI', 'AnglestoreRtildeIcommeasapprxconstsortedmaxdiff_max', 'AnglestoreRtildeIcommeasapprxconstsortedmindiff_min'])
