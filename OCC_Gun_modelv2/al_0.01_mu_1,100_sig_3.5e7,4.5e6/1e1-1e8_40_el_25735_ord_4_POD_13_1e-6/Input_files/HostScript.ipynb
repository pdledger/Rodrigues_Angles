# %%
from time import time
import numpy as np
from matplotlib import pyplot as plt
import os
# Please edit this line to provide the to the root directory of your copy of MPT-Calculator
Your_Path = r'/home/paul/Coding/MPT-Calculator-Feb2024/MPT-Calculator'
os.chdir(Your_Path)
os.getcwd()


from main import main

# %%
from main import main
comparison_eig_p = np.zeros((40,6), dtype=complex)
comparison_ndofs_p = np.zeros(6)
start_time = time()
for p in [0,1,2,3,4,5]:
    print('Solving for order =',p)
    Return_Dict = main(geometry='OCC_Gun_modelv2.py', use_OCC=True, use_POD=True,order=p);
    comparison_eig_p[:,p] = Return_Dict['EigenValues'][:,0]
    comparison_ndofs_p[p] = Return_Dict['NDOF'][1]
# Out:
# Solving for order = 0
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'ngsolve_version': 'Netgen x.x', 'mesh_dim': 3…
# Updated alpha from OCC file. Alpha=0.01
# OCC_Gun_modelv2.geo
# 1 air Steel
# [0, 1, 2] 3 ['air', 'Alu', 'Steel']
# Mesh Contains Prisms? True
# N Prisms: 5321, N Tets: 20414
# 1 air Steel
# [0, 1, 2] 3 ['air', 'Alu', 'Steel']
# /home/paul/Coding/MPT-Calculator-Feb2024/MPT-Calculator/main.py:279: UserWarning: It looks like the main function was invoked from a jupyter notebook.
# Currently saving a .ipynb file is done by copying the most recent file in the .ipynb_checkpoints folder.
# Unless you saved the file before running the code, this may not be the correct file.
# ...

# %%
frequencies = [1e4]
Return_Dict = main(geometry='OCC_Gun_modelv2.py', use_OCC=True, order=4,frequency_array=frequencies,curve_degree=1);
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'ngsolve_version': 'Netgen x.x', 'mesh_dim': 3…
# 10.0 5.9470828988194474e-05
# Updated alpha from OCC file. Alpha=0.01
# OCC_Gun_modelv2.geo
# 1 air Steel
# [0, 1, 2] 3 ['air', 'Alu', 'Steel']
# Mesh Contains Prisms? True
# N Prisms: 5321, N Tets: 20414
# 1 air Steel
# [0, 1, 2] 3 ['air', 'Alu', 'Steel']
# /home/paul/Coding/MPT-Calculator-Feb2024/MPT-Calculator/main.py:279: UserWarning: It looks like the main function was invoked from a jupyter notebook.
# Currently saving a .ipynb file is done by copying the most recent file in the .ipynb_checkpoints folder.
# Unless you saved the file before running the code, this may not be the correct file.
# ...
