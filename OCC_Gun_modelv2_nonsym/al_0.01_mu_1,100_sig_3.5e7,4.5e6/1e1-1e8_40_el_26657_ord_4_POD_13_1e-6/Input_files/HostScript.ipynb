# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def SplitTensor(TensorArray,N):
    Rstore = np.zeros((N,3,3))
    Istore = np.zeros((N,3,3))
    Rtildestore = np.zeros((N,3,3))
    for n in range(N):
        Mlist = TensorArray[n,:]
        Mten = np.array([[Mlist[0], Mlist[1], Mlist[2]],[Mlist[3], Mlist[4], Mlist[5]],[Mlist[6], Mlist[7], Mlist[8]]])
        Rtilde = np.real(Mten)
        I = np.imag(Mten)
        R = np.real(Mten)-N0
        for i in range(3):
            for j in range(3):
                Rstore[n,i,j]=R[i,j]
                Istore[n,i,j]=I[i,j]
                Rtildestore[n,i,j]=Rtilde[i,j]

    return Rstore,Istore,Rtildestore

# %%
plt.figure()
for p in [2,3,4]:
    #if p > 3:
    #    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_1,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_20413_ord_"+str(p)+"_POD_13_1e-6/Data/"
    #else:
    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2/al_0.01_mu_1,100_sig_3.5e7,4.5e6/1e1-1e8_40_el_25735_ord_"+str(p)+"_POD_13_1e-6/Data/"
    
    #    
    #directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_27541_ord_"+str(p)+"_POD_13_1e-6/Data/"
#    else:
    #if p > 4:
    #    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv3/al_0.01_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_29917_ord_"+str(p)+"_POD_13_1e-6/Data/"
    #else:
    #    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv4/al_0.01_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_32293_ord_"+str(p)+"_POD_13_1e-6/Data/"
    
        
    print(directory)
    TensorArray = np.genfromtxt(directory+'Tensors.csv', dtype=complex, delimiter=', ')
    N0 =          np.genfromtxt(directory+'N0.csv', dtype=float, delimiter=',')
    Frequencies = np.genfromtxt(directory+'Frequencies.csv', dtype=float, delimiter=', ')
    N = len(Frequencies)
    Rstore,Istore,Rtildestore=SplitTensor(TensorArray,N)
    plt.semilogx(Frequencies,Istore[:,0,0],label='Order='+str(p)+' BL')

    PODTensorArray = np.genfromtxt(directory+'PODTensors.csv', dtype=complex, delimiter=', ')
    N0 =          np.genfromtxt(directory+'N0.csv', dtype=float, delimiter=',')
    PODFrequencies = np.genfromtxt(directory+'PODFrequencies.csv', dtype=float, delimiter=', ')
    NPOD = len(PODFrequencies)
    Rstore,Istore,Rtildestore=SplitTensor(PODTensorArray,NPOD)
    plt.semilogx(PODFrequencies,Istore[:,0,0],'x',label='Order='+str(p)+' BL POD')
    

plt.xlabel(r"$\omega$ [rad/s]")
plt.ylabel(r"$({\cal I})_{ij}$ [m$^3$]")

plt.legend()
#plt.savefig("Alpha_0.01_gunv2.bl-pconv.pdf")
plt.show()
# Out:
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2/al_0.01_mu_1,100_sig_3.5e7,4.5e6/1e1-1e8_40_el_25735_ord_2_POD_13_1e-6/Data/
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2/al_0.01_mu_1,100_sig_3.5e7,4.5e6/1e1-1e8_40_el_25735_ord_3_POD_13_1e-6/Data/
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2/al_0.01_mu_1,100_sig_3.5e7,4.5e6/1e1-1e8_40_el_25735_ord_4_POD_13_1e-6/Data/

# %%
for p in [4,5]:
    #if
    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_1,100_sig_3.5e7,4.5e6/1e1-1e8_40_el_25735_ord_"+str(p)+"_POD_13_1e-6/Data/"
    
    #    
    #directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_27541_ord_"+str(p)+"_POD_13_1e-6/Data/"
#    else:
    #if p > 4:
    #    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv3/al_0.01_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_29917_ord_"+str(p)+"_POD_13_1e-6/Data/"
    #else:
    #    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv4/al_0.01_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_32293_ord_"+str(p)+"_POD_13_1e-6/Data/"
    
        
    print(directory)
    TensorArray = np.genfromtxt(directory+'Tensors.csv', dtype=complex, delimiter=', ')
    N0 =          np.genfromtxt(directory+'N0.csv', dtype=float, delimiter=',')
    Frequencies = np.genfromtxt(directory+'Frequencies.csv', dtype=float, delimiter=', ')
    N = len(Frequencies)
    Rstore,Istore,Rtildestore=SplitTensor(TensorArray,N)
    plt.semilogx(Frequencies,Istore[:,0,0],label='Order='+str(p)+'BL')

plt.legend()
plt.show()
# Out:
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_1,100_sig_3.5e7,4.5e6/1e1-1e8_40_el_25735_ord_4_POD_13_1e-6/Data/
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_1,100_sig_3.5e7,4.5e6/1e1-1e8_40_el_25735_ord_5_POD_13_1e-6/Data/

# %%
s=10
for p in [3,4]:
    #if
    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_1,100_sig_3.5e7,4.5e6/1e1-1e8_40_el_25735_ord_"+str(p)+"_POD_13_1e-6/Data/"
    
    #    
    #directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_27541_ord_"+str(p)+"_POD_13_1e-6/Data/"
#    else:
    #if p > 4:
    #    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv3/al_0.01_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_29917_ord_"+str(p)+"_POD_13_1e-6/Data/"
    #else:
    #    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv4/al_0.01_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_32293_ord_"+str(p)+"_POD_13_1e-6/Data/"
    
        
    print(directory)
    TensorArray = np.genfromtxt(directory+'Tensors.csv', dtype=complex, delimiter=', ')
    N0 =          np.genfromtxt(directory+'N0.csv', dtype=float, delimiter=',')
    Frequencies = np.genfromtxt(directory+'Frequencies.csv', dtype=float, delimiter=', ')
    N = len(Frequencies)
    Frequencies = Frequencies /s**2
    TensorArray = s**3 * TensorArray
    Rstore,Istore,Rtildestore=SplitTensor(TensorArray,N)
    plt.semilogx(Frequencies,Istore[:,0,0],label=r'Order='+str(p)+r'BL scaled $\alpha=10^{-3}$')

    
for p in [3,4]:
    #if p > 3:
    #    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_1,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_20413_ord_"+str(p)+"_POD_13_1e-6/Data/"
    #else:
    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2/al_0.01_mu_1,100_sig_3.5e7,4.5e6/1e1-1e8_40_el_25735_ord_"+str(p)+"_POD_13_1e-6/Data/"
    

        
    print(directory)
    TensorArray = np.genfromtxt(directory+'Tensors.csv', dtype=complex, delimiter=', ')
    N0 =          np.genfromtxt(directory+'N0.csv', dtype=float, delimiter=',')
    Frequencies = np.genfromtxt(directory+'Frequencies.csv', dtype=float, delimiter=', ')
    N = len(Frequencies)
    Rstore,Istore,Rtildestore=SplitTensor(TensorArray,N)
    plt.semilogx(Frequencies,Istore[:,0,0],label='Order='+str(p)+'BL')

    PODTensorArray = np.genfromtxt(directory+'PODTensors.csv', dtype=complex, delimiter=', ')
    N0 =          np.genfromtxt(directory+'N0.csv', dtype=float, delimiter=',')
    PODFrequencies = np.genfromtxt(directory+'PODFrequencies.csv', dtype=float, delimiter=', ')
    NPOD = len(PODFrequencies)
    Rstore,Istore,Rtildestore=SplitTensor(PODTensorArray,NPOD)
    plt.semilogx(PODFrequencies,Istore[:,0,0],'x',label='Order='+str(p)+'BL')
    
plt.xlabel(r"$\omega$ [rad]/s")
plt.ylabel(r"$({\cal I})_{ij}$ [m$^3$]")     
plt.legend()
#plt.savefig("Alpha_0.01_gunv2.bl-scale-compare.pdf")
plt.show()
# Out:
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_1,100_sig_3.5e7,4.5e6/1e1-1e8_40_el_25735_ord_3_POD_13_1e-6/Data/
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_1,100_sig_3.5e7,4.5e6/1e1-1e8_40_el_25735_ord_4_POD_13_1e-6/Data/
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2/al_0.01_mu_1,100_sig_3.5e7,4.5e6/1e1-1e8_40_el_25735_ord_3_POD_13_1e-6/Data/
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2/al_0.01_mu_1,100_sig_3.5e7,4.5e6/1e1-1e8_40_el_25735_ord_4_POD_13_1e-6/Data/
