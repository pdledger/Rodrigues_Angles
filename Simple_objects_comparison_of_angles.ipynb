# %%
from main import *

# %% [markdown]
# ## Rotated Rectangular Block

# %%
DirList=["OCC_cube_prism_rotated/al_0.001_mu_1_sig_1e6/1e1-1e8_40_el_19635_ord_3_POD_13_1e-7/Data/"]
SaveRIList=[]
SaveRtilde=[]

MaxOmega=1e6
for directory in DirList:
    print(directory)
    RIResults,RtildeIResults=main(directory,MaxOmega)
# Out:
# OCC_cube_prism_rotated/al_0.001_mu_1_sig_1e6/1e1-1e8_40_el_19635_ord_3_POD_13_1e-7/Data/
# Opening files from this path =  OCC_cube_prism_rotated/al_0.001_mu_1_sig_1e6/1e1-1e8_40_el_19635_ord_3_POD_13_1e-7/Data/

# %%
print(RIResults.keys())

Frequencies=RIResults["Frequencies"]
MinAnglestoreRI=RIResults["MinAnglestoreRI"]
AnglestoreRIfmeasapprxconstsortedmaxdiff_max=RIResults["AnglestoreRIfmeasapprxconstsortedmaxdiff_max"]
fig=plt.figure()
plt.semilogx(Frequencies,MinAnglestoreRI,label=r'$d_R({\cal R},{\cal I})$')
plt.semilogx(Frequencies,AnglestoreRIfmeasapprxconstsortedmaxdiff_max,'x',label=r'Approx $d_R({\cal R},{\cal I})$ from  $d_E({\cal R},{\cal I})$ ')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.legend()
plt.show()
plt.savefig("OCC_cube_prism_rotated_dRanddE_metrics_al_0.001_mu_1_sig_1e6_ord3.pdf")
# Out:
# dict_keys(['Frequencies', 'MinAnglestoreRI', 'AnglestoreRIfmeasapprxconstsortedmaxdiff_max'])

# %%
print(RtildeIResults.keys())

Frequencies=RtildeIResults["Frequencies"]
MinAnglestoreRI=RtildeIResults["MinAnglestoreRtildeI"]
AnglestoreRtildeIfmeasapprxconstsortedmaxdiff_max=RtildeIResults["AnglestoreRtildeIfmeasapprxconstsortedmaxdiff_max"]
fig=plt.figure()
plt.semilogx(Frequencies,MinAnglestoreRtildeI,label=r'$d_R(\tilde{\cal R},{\cal I})$')
plt.semilogx(Frequencies,AnglestoreRtildeIfmeasapprxconstsortedmaxdiff_max,'x',label=r'Approx $d_R(\tilde{\cal R},{\cal I})$ from  $d_E({\cal R},{\cal I})$ ')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'$\theta$ [rad]')
plt.legend()
plt.show()
plt.savefig("OCC_cube_prism_rotated_dRanddE_metrics_al_0.001_mu_1_sig_1e6_ord3.pdf")
