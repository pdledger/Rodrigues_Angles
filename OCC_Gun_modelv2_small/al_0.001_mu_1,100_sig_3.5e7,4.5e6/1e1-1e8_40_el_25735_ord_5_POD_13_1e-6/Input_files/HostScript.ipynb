# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def SplitTensor(TensorArray,N):
    Rstore = np.zeros((N,3,3))
    Istore = np.zeros((N,3,3))
    Rtildestore = np.zeros((N,3,3))
    for n in range(N):
        Mlist = TensorArray[n,:]
        Mten = np.array([[Mlist[0], Mlist[1], Mlist[2]],[Mlist[3], Mlist[4], Mlist[5]],[Mlist[6], Mlist[7], Mlist[8]]])
        Rtilde = np.real(Mten)
        I = np.imag(Mten)
        R = np.real(Mten)-N0
        for i in range(3):
            for j in range(3):
                Rstore[n,i,j]=R[i,j]
                Istore[n,i,j]=I[i,j]
                Rtildestore[n,i,j]=Rtilde[i,j]

    return Rstore,Istore,Rtildestore

# %%
plt.figure()
for p in [1,2,3,4,5,6]:
    #if p > 3:
    #    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_1,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_20413_ord_"+str(p)+"_POD_13_1e-6/Data/"
    #else:
    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_22219_ord_"+str(p)+"_POD_13_1e-6/Data/"
    
    #    
    #directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_27541_ord_"+str(p)+"_POD_13_1e-6/Data/"
#    else:
    #if p > 4:
    #    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv3/al_0.01_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_29917_ord_"+str(p)+"_POD_13_1e-6/Data/"
    #else:
    #    directory="/home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv4/al_0.01_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_32293_ord_"+str(p)+"_POD_13_1e-6/Data/"
    
        
    print(directory)
    TensorArray = np.genfromtxt(directory+'Tensors.csv', dtype=complex, delimiter=', ')
    N0 =          np.genfromtxt(directory+'N0.csv', dtype=float, delimiter=',')
    Frequencies = np.genfromtxt(directory+'Frequencies.csv', dtype=float, delimiter=', ')
    N = len(Frequencies)
    Rstore,Istore,Rtildestore=SplitTensor(TensorArray,N)
    plt.semilogx(Frequencies,Istore[:,0,0],label='Order='+str(p)+'BL')

plt.legend()
plt.show()
# Out:
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_22219_ord_1_POD_13_1e-6/Data/
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_22219_ord_2_POD_13_1e-6/Data/
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_22219_ord_3_POD_13_1e-6/Data/
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_22219_ord_4_POD_13_1e-6/Data/
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_22219_ord_5_POD_13_1e-6/Data/
# /home/paul/Coding/PaulResults/PaulMPTResults/Results/OCC_Gun_modelv2_small/al_0.001_mu_100,1_sig_4.5e6,3.5e7/1e1-1e8_40_el_22219_ord_6_POD_13_1e-6/Data/
